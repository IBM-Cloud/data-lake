# %% [markdown]
# # Modeling Traffic Congestion using Weather

# %% [markdown]
# Accurate anticipation of traffic congestion is an important problem and can potentially yield immense benefits towards improving travel conditions for commuters as well as helping various industries that rely on ground transportation. Bad weather such as rain and snow is one of the biggest factors causing traffic congestion. In this notebook, we aim to investigate this problem and provide an overview of the steps that might be required to tackle it in an end-to-end manner, from data exploration to data transformation and using machine learning to obtain models that can be used to predict the real-time traffic congestion using historical traffic congestion and weather conditions.
# In this notebook, we will use traffic and weather data from the city of Chicago. This data is available on the IBM Cloud Object Storage (COS). We will use IBM Cloud SQL Query to explore and transform this traffic and weather data to obtain useful data features that can then be used to train a simple machine learning model.
#
# In most typical data science and machine learning pipelines, a number of data preparation steps involved before training predictive models. Particularly, one may want to explore the data to determine which variables might be useful, transform the data, and fuse and join data from multiple different sources. These are the high level steps that we will be following in this notebook as well. We will first explore, transform and join data leveraging various capabilities available through Cloud SQL Query, to obtain useful data features, which we will then use to build predictive models using scikit-learn.

# %% [markdown]
# ## Table of contents
# 1. [Setup and Configuration](#setup)<br>
# 2. [Data Exploration using SQL Query](#exploration)<br>
# 3. [Step by step ETL - Spatiotemporal Joins using SQL Query](#etl)<br>
# 4. [Compond ETL](#compoundetl)<br>
# 5. [Machine Learning Model Training](#train)<br>
# 6. [Traffic Congestion Prediction](#prediction)<br>
# 7. [Predicted Traffic Congestion Visualization](#viz)<br>

# %% [markdown]
# ### <a name="setup"></a> 1. Setup and Configuration

# %% [markdown]
# Let us first install all the dependencies that we will need and configure IBM Cloud SQL Query

# %%
# %%capture
# !conda install -y pyarrow
# !pip install --user ibmcloudsql
# !pip install folium
import ibmcloudsql
import getpass
from sklearn import tree
import folium
targeturl = ''

# %%
apikey=getpass.getpass('Enter IBM Cloud API Key (leave empty to use previous one): ') or apikey
instnacecrn=input('Enter SQL Query Instance CRN (leave empty to use previous one): ') or instnacecrn
if targeturl == '':
    targeturl=input('Enter target URL for SQL results: ')
else:
    targeturl=input('Enter target URL for SQL results (leave empty to use ' + targeturl + '): ') or targeturl
sqlClient = ibmcloudsql.SQLQuery(apikey, instnacecrn, client_info='Traffic Weather')
sqlClient.logon()
# Out:
# Enter IBM Cloud API Key (leave empty to use previous one): ········
# Enter SQL Query Instance CRN (leave empty to use previous one): crn:v1:bluemix:public:sql-query:us-south:a/3ac874e10c8ca426580dc63d4462cbdd:a78efba7-0015-4262-98bc-397376ded16b::
# Enter target URL for SQL results (leave empty to use cos://us-geo/sqltest/result):

# %% [markdown]
# ### <a name="exploration"></a> 2. Data Exploration using SQL Query

# %% [markdown]
# The data that we will use in this notebook is stored in *4 different objects in COS*.
#
# - **cos://us-geo/sql/segment_locations.parquet** contains the **metadata for each of the road segments**
#
# - **cos://us-geo/sql/traffic.parquet** contains the **historical traffic congestion data for each of the road segments**
#
# - **cos://us-geo/sql/weather_sites.parquet** contains the **metadata for each of the weather sites**
#
# - **cos://us-geo/sql/weather.parquet** contains the **historical weather data for each of the weather sites**
#
# Let us take a quick look at the data.

# %% [markdown]
# **What does the traffic data look like?**

# %%
sql = "SELECT SegmentID, ST_AsText(Segment) as RoadSegment FROM cos://us-east/mytestbucket123/segment_locations.parquet STORED AS PARQUET INTO {}".format(targeturl)
traffic_meta_explore = sqlClient.run_sql(sql)
if isinstance(traffic_meta_explore, str):
    print(traffic_meta_explore)
traffic_meta_explore.head(10)
# Out:
#    SegmentID                                        RoadSegment
# 0       1088  LINESTRING (-87.6413654096 41.6634679215, -87....
# 1        148  LINESTRING (-87.6662077421 41.8523321221, -87....
# 2        463  LINESTRING (-87.6727255878 41.7211640089, -87....
# 3        496  LINESTRING (-87.7526573727 41.7970886104, -87....
# 4       1238  LINESTRING (-87.644021 41.743359, -87.643756 4...
# 5        471  LINESTRING (-87.594731404 41.7222769494, -87.6...
# 6       1084  LINESTRING (-87.7191682775 41.6622990645, -87....
# 7        897  LINESTRING (-87.6537610863 41.9855554936, -87....
# 8        858  LINESTRING (-87.7782350055 41.9733282922, -87....
# 9       1025  LINESTRING (-87.6367064128 41.8819140751, -87....

# %%
sql = "SELECT COUNT(DISTINCT SegmentID) FROM cos://us-east/mytestbucket123/segment_locations.parquet STORED AS PARQUET INTO {}".format(targeturl)
segment_id_count = sqlClient.run_sql(sql)
if isinstance(segment_id_count, str):
    print(segment_id_count)
segment_id_count.head()
# Out:
#    count(DISTINCT SegmentID)
# 0                       1257

# %%
sql = "SELECT * FROM cos://us-geo/sql/traffic.parquet STORED AS PARQUET LIMIT 10 INTO {}".format(targeturl)
traffic_explore = sqlClient.run_sql(sql)
if isinstance(traffic_explore, str):
    print(traffic_explore)
traffic_explore.head(10)
# Out:
#                      TIME  SEGMENTID  SPEED
# 0  04/09/2018 11:10:30 PM       1090     -1
# 1  04/09/2018 08:40:14 AM         57     20
# 2  04/09/2018 10:20:49 PM       1232     -1
# 3  04/09/2018 06:21:05 PM        960     11
# 4  04/10/2018 03:10:32 PM        300     21
# 5  04/08/2018 08:50:20 PM        187     21
# 6  04/10/2018 10:40:06 AM          4     23
# 7  04/08/2018 06:01:20 PM        967     -1
# 8  04/08/2018 02:40:12 PM        294     19
# 9  04/10/2018 08:31:05 PM        893     42

# %% [markdown]
# **What does the weather data look like?**

# %%
sql = "SELECT * FROM cos://us-geo/sql/weather_sites.parquet STORED AS PARQUET INTO {}".format(targeturl)
weather_meta_explore = sqlClient.run_sql(sql)
if isinstance(weather_meta_explore, str):
    print(weather_meta_explore)
weather_meta_explore.head(10)
# Out:
#        SiteId  Latitude  Longitude
# 0  2265659164  42.43317  -88.50244
# 1  2260359280  42.11351  -87.24051
# 2  2245275119  41.21886  -88.31384
# 3  2252346520  41.63551  -87.10202
# 4  2255084035  41.79811  -87.72607
# 5  2247889779  41.37234  -87.21756
# 6  2255941743  41.84923  -87.35632
# 7  2250636828  41.53433  -87.83850
# 8  2257748129  41.95708  -88.35229
# 9  2264752903  42.37830  -87.12344

# %%
sql = "SELECT COUNT(DISTINCT SiteID) FROM cos://us-geo/sql/weather_sites.parquet STORED AS PARQUET INTO {}".format(targeturl)
weather_site_count = sqlClient.run_sql(sql)
if isinstance(weather_site_count, str):
    print(weather_site_count)
weather_site_count.head()
# Out:
#    count(DISTINCT SiteID)
# 0                      22

# %%
sql = "SELECT * FROM cos://us-geo/sql/weather.parquet STORED AS PARQUET INTO {}".format(targeturl)
weather_explore = sqlClient.run_sql(sql)
if isinstance(weather_explore, str):
    print(weather_explore)
weather_explore.head(10)
# Out:
#        SiteId            DateHrGmt  SurfaceTemperatureFahrenheit  \
# 0  2260359280  04/09/2018 18:00:00                          32.3
# 1  2258638047  04/12/2018 15:00:00                          61.3
# 2  2263045486  04/06/2018 02:00:00                          33.0
# 3  2258638047  04/01/2018 04:00:00                          31.4
# 4  2250636828  04/09/2018 01:00:00                          32.3
# 5  2255084035  04/03/2018 03:00:00                          36.8
# 6  2263909103  04/08/2018 17:00:00                          29.9
# 7  2245275119  04/06/2018 19:00:00                          35.2
# 8  2246165668  04/03/2018 20:00:00                          40.5
# 9  2259508022  04/07/2018 10:00:00                          24.0
#
#    SurfaceDewpointTemperatureFahrenheit  SurfaceWetBulbTemperatureFahrenheit  \
# 0                                  27.7                                 30.5
# 1                                  54.9                                 57.4
# 2                                  28.6                                 31.3
# 3                                  26.5                                 29.6
# 4                                  19.8                                 28.2
# 5                                  31.3                                 34.4
# 6                                  20.0                                 26.7
# 7                                  24.5                                 31.3
# 8                                  39.9                                 40.2
# 9                                  16.9                                 22.0
#
#    RelativeHumidityPercent  SurfaceAirPressureMillibars  CloudCoveragePercent  \
# 0                       83                       1002.0                    17
# 1                       80                        977.0                    72
# 2                       84                        991.0                   100
# 3                       82                        995.0                   100
# 4                       60                        994.0                   100
# 5                       80                        988.0                   100
# 6                       66                        999.0                     1
# 7                       65                        993.0                    98
# 8                       98                        975.0                   100
# 9                       75                        999.0                    18
#
#    WindChillTemperatureFahrenheit  ApparentTemperatureFahrenheit  \
# 0                            23.4                           23.4
# 1                            61.3                           61.3
# 2                            24.3                           24.3
# 3                            21.5                           21.5
# 4                            25.8                           25.8
# 5                            29.7                           29.7
# 6                            22.4                           22.4
# 7                            24.4                           24.4
# 8                            33.6                           33.6
# 9                            11.4                           11.4
#
#                      ...                     WindDirectionDegrees  \
# 0                    ...                                       14
# 1                    ...                                      250
# 2                    ...                                      168
# 3                    ...                                      319
# 4                    ...                                       73
# 5                    ...                                      116
# 6                    ...                                       77
# 7                    ...                                      288
# 8                    ...                                       27
# 9                    ...                                      331
#
#    PrecipitationPreviousHourInches  DownwardSolarRadiationWsqm  \
# 0                            0.000                         909
# 1                            0.000                         593
# 2                            0.010                           0
# 3                            0.000                           0
# 4                            0.001                           0
# 5                            0.000                           0
# 6                            0.000                         866
# 7                            0.000                         529
# 8                            0.120                          23
# 9                            0.000                           0
#
#    DiffuseHorizontalRadiationWsqm  DirectNormalIrradianceWsqm  \
# 0                              92                         994
# 1                              80                         902
# 2                               0                           0
# 3                               0                           0
# 4                               0                           0
# 5                               0                           0
# 6                              89                        1004
# 7                             411                         145
# 8                              23                           0
# 9                               0                           0
#
#    MslPressureMillibars  HeatIndexFahrenheit  SnowfallInches  \
# 0                1023.0                 32.3             0.0
# 1                1002.0                 61.3             0.0
# 2                1017.0                 33.0             0.0
# 3                1022.0                 31.4             0.0
# 4                1019.0                 32.3             0.0
# 5                1012.0                 36.8             0.0
# 6                1021.0                 29.9             0.0
# 7                1016.0                 35.2             0.0
# 8                 998.0                 40.5             0.0
# 9                1022.0                 24.0             0.0
#
#    SurfaceWindGustsMph  ReferenceEvapotranspirationInchesPerHour
# 0                 18.3                                  0.000315
# 1                 32.9                                  0.000512
# 2                 20.6                                  0.000000
# 3                 41.4                                  0.000000
# 4                 12.1                                  0.000039
# 5                 15.7                                  0.000039
# 6                 12.6                                  0.000354
# 7                 44.7                                  0.000276
# 8                 40.6                                  0.000157
# 9                 25.5                                  0.000000
#
# [10 rows x 21 columns]

# %% [markdown]
# In summary, we have **historical traffic congestion data for total of 1257 road segments** and **weather data for 22 weather sites**, stored in the following objects:
#
# **(1) Traffic Metadata** - This object contains metadata related to road segments, i.e, the road segment identifiers and the line segment geometry for the road segments.
#
# **(2) Traffic Data** - This object contains traffic data for road segments from the city of Chicago. Specifically, it consists of the road segment identifiers, timestamps, and speeds, with a sampling rate of 10 minutes. Congestion on a road segment at a given instance in time is defined as the (speed / reference_speed). We will assume the reference speed to be 30 mph. A congestion value less than 1 means that there is no congestion, whereas a value greater than 1 implies a congested road.
#
# **(3) Weather Metadata** - This object contains metadata related to weather stations, i.e, the weather station identifiers and their location (represented by the latitude and longitude) in the city of Chicago.
#
# **(4) Weather Data** - This object contains weather data for weather sites. Specifically, it consists of weather station identifiers, timestamps, and  values for various weather attributes, including surface temperature, precipitation, snowfall, wind speed, etc.

# %% [markdown]
# ### <a name="etl"></a> 3. ETL - Spatiotemporal Joins using SQL Query

# %% [markdown]
# Now that we know that the traffic and weather data resides in multiple different buckets, we need to join this data together to obtain data features for our predictive machine learning model. We can accomplish this using the various spatial and temporal join functions that SQL Query provides. We can do this ETL in a single compound query or break it down into a multiple steps. In this section, we use the step by step approach to better explain the process. [Section 4](#compoundetl) has the same steps in a single compound query. So, one could also skip this section entirely and directly run the cell in [section 4](#compoundetl). If you run cells in this section, there is no need to run the cells in the next section since they both have the same effect.
#
# **(1) Join Traffic and Weather Metadata for Road Segments in the city of Chicago and nearby suburbs**: We first sub-select segment locations in Chicago and its neighboring suburbs through a `ST_Contains` spatial operation. We then perform a spatial distance based cross join between the sub-selected segment locations and the weather site locations using the `ST_Distance` spatial predicate and pick the closest distance pairs to obtain corresponding weather site identifiers for every road segment identifier.

# %%
metadata_join_sql = """
SELECT SegmentID,
	SiteId FROM
		(SELECT *, dense_rank() OVER (PARTITION BY SegmentID
                                      ORDER BY dist ASC) AS rank FROM
					(SELECT SegmentID, SiteId, ST_Distance(SEGMENT, ST_Point(Longitude, Latitude)) AS dist
						FROM cos://us-geo/sql/weather_sites.parquet STORED AS PARQUET
						CROSS JOIN
								(SELECT SegmentID, SEGMENT
									FROM cos://us-east/mytestbucket123/segment_locations.parquet STORED AS PARQUET
									WHERE ST_Contains(ST_WKTToSQL('POLYGON((-87.66182361726857 42.013649516597454,-87.78404651765919 42.00956804496257,-87.78541980867482 41.90335786993515,-87.71126209383107 41.74268615114427,-87.61513172273732 41.71296382783499,-87.54784046297169 41.746784702779486,-87.61650501375294 41.86246067685847,-87.66182361726857 42.013649516597454))'), SEGMENT))))
WHERE rank <= 1 INTO {}
""".format(targeturl)
metadata_join_jobId = sqlClient.submit_sql(metadata_join_sql)
job_status = sqlClient.wait_for_job(metadata_join_jobId)
metadata_join_location = sqlClient.get_job(metadata_join_jobId)['resultset_location']

# %% [markdown]
# **(2) Create Traffic Congestion Timeseries for each Road Segment**: We create per- road segment traffic congestion timeseries using the `TIME_SERIES` function. The dataset consists of -1 speeds when no data is available at a given time. We will filter out these values.

# %%
traffic_ts_sql = """
SELECT SegmentID,
	TIME_SERIES(TS_TIMESTAMP(to_timestamp(TIME, "MM/dd/yyyy hh:mm:ss aaa")), speed/30) AS ts
FROM cos://us-geo/sql/traffic.parquet STORED AS PARQUET
WHERE speed >= 0
GROUP BY SegmentID INTO {} STORED AS PARQUET
""".format(targeturl)
traffic_ts_jobId = sqlClient.submit_sql(traffic_ts_sql)
job_status = sqlClient.wait_for_job(traffic_ts_jobId)
traffic_ts_location = sqlClient.get_job(traffic_ts_jobId)['resultset_location']

# %% [markdown]
# **(3) Create Precipitation Timeseries for each Weather Site**: We create per- weather site timeseries for precipitation values using the `TIME_SERIES` function.

# %%
precipitation_ts_sql = """
SELECT SiteId,
	TIME_SERIES(TS_TIMESTAMP(to_timestamp(DateHrGmt, "MM/dd/yyyy HH:mm:ss")), PrecipitationPreviousHourInches) AS ts
FROM cos://us-geo/sql/weather.parquet STORED AS PARQUET
GROUP BY SiteId INTO {} STORED AS PARQUET
""".format(targeturl)
precipitation_ts_jobId = sqlClient.submit_sql(precipitation_ts_sql)
job_status = sqlClient.wait_for_job(precipitation_ts_jobId)
precipitation_ts_location = sqlClient.get_job(precipitation_ts_jobId)['resultset_location']

# %% [markdown]
# **(4) Create Snow Timeseries for each Weather Site**: We create per- weather site timeseries for snow values using the `TIME_SERIES` function.

# %%
snow_ts_sql = """
SELECT SiteId, 
        TIME_SERIES(TS_TIMESTAMP(to_timestamp(DateHrGmt, "MM/dd/yyyy HH:mm:ss")), SnowfallInches) AS ts
FROM cos://us-geo/sql/weather.parquet STORED AS PARQUET
GROUP BY SiteId INTO {} STORED AS PARQUET
""".format(targeturl)
snow_ts_jobId = sqlClient.submit_sql(snow_ts_sql)
job_status = sqlClient.wait_for_job(snow_ts_jobId)
snow_ts_location = sqlClient.get_job(snow_ts_jobId)['resultset_location']

# %% [markdown]
# **(5) Join the Traffic Congestion Timeseries with the table obtained in step (1)**: In this step, we will join the traffic congestion timeseries obtained in step (2) with the metadata obtained in step (1), so that we have closest weather site identifier for every road segment identifier.

# %%
metadata_traffic_ts_join_sql = """
SELECT traffic_ts.SegmentID, 
        traffic_ts.ts, 
        metadata.SiteId 
FROM {} AS metadata, 
        {} STORED AS PARQUET AS traffic_ts
WHERE traffic_ts.SegmentID = metadata.SegmentID INTO {} STORED AS PARQUET
""".format(metadata_join_location, traffic_ts_location, targeturl)
metadata_traffic_ts_join_jobId = sqlClient.submit_sql(metadata_traffic_ts_join_sql)
job_status = sqlClient.wait_for_job(metadata_traffic_ts_join_jobId)
metadata_traffic_ts_join_location = sqlClient.get_job(metadata_traffic_ts_join_jobId)['resultset_location']

# %% [markdown]
# **(6) Join the Traffic Congestion Timeseries and the Precipitation Weather timeseries**: We join the traffic congestion timeseries with metadata  obtained in step (5) with the precipitation timeseries obtained in step (3) using the `TS_LEFT_JOIN` timeseries function. We use a left join here because the traffic congestion timeseries are sampled at a higher rate than the weather site timeseries. To interpolate any missing or null values in the precipitation timeseries, we use the `TS_INTERPOLATOR_PREV` interpolation function.

# %%
traffic_ts_join_precipitation_ts_sql = """
SELECT SegmentID, 
        precipitation_ts.SiteId, 
        TS_LEFT_JOIN(id_joined_traffic_ts.ts, precipitation_ts.ts, TS_INTERPOLATOR_PREV(0.0)) as ts1_ts2
FROM {} STORED AS PARQUET AS id_joined_traffic_ts, 
        {} STORED AS PARQUET AS precipitation_ts
WHERE id_joined_traffic_ts.SiteId = precipitation_ts.SiteId INTO {} STORED AS PARQUET
""".format(metadata_traffic_ts_join_location, precipitation_ts_location, targeturl)
traffic_ts_join_precipitation_ts_jobId = sqlClient.submit_sql(traffic_ts_join_precipitation_ts_sql)
job_status = sqlClient.wait_for_job(traffic_ts_join_precipitation_ts_jobId)
traffic_ts_join_precipitation_ts_location = sqlClient.get_job(traffic_ts_join_precipitation_ts_jobId)['resultset_location']

# %% [markdown]
# **(7) Join the Traffic Congestion Timeseries and the Snow Weather timeseries**: We join the traffic congestion timeseries with metadata obtained in step (5) with the snow timeseries obtained in step (4) using the `TS_LEFT_JOIN` timeseries function. To interpolate any missing or null values in the snow timeseries, we use the `TS_INTERPOLATOR_PREV` interpolation function.

# %%
traffic_ts_join_snow_ts_sql = """
SELECT SegmentID, 
        snow_ts.SiteId, 
        TS_LEFT_JOIN(id_joined_traffic_ts.ts, snow_ts.ts, TS_INTERPOLATOR_PREV(0.0)) as ts1_ts2
FROM {} STORED AS PARQUET AS id_joined_traffic_ts,
        {} STORED AS PARQUET AS snow_ts
WHERE id_joined_traffic_ts.SiteId = snow_ts.SiteId INTO {} STORED AS PARQUET
""".format(metadata_traffic_ts_join_location, snow_ts_location, targeturl)
traffic_ts_join_snow_ts_jobId = sqlClient.submit_sql(traffic_ts_join_snow_ts_sql)
job_status = sqlClient.wait_for_job(traffic_ts_join_snow_ts_jobId)
traffic_ts_join_snow_ts_location = sqlClient.get_job(traffic_ts_join_snow_ts_jobId)['resultset_location']

# %% [markdown]
# **(8) Perform Temporal Join on on the previously aligned timeseries**: We join the three timeseries, traffic congestion, precipitation and snow together using the `TS_VECTOR3` timeseries function. The `TS_TAKE_INDEX` function gets the appropriate timeseries from the previously joined timeseries.

# %%
join_all_ts_sql = """
SELECT traffic_precipitation_joined_ts.SegmentID, 
        TS_VECTOR3(TS_INDEX(traffic_precipitation_joined_ts.ts1_ts2, 0), 
                    TS_INDEX(traffic_precipitation_joined_ts.ts1_ts2, 1), 
                    TS_INDEX(traffic_snow_joined_ts.ts1_ts2, 1))
        AS joined_ts 
FROM {} STORED AS PARQUET AS traffic_precipitation_joined_ts, 
        {} STORED AS PARQUET AS traffic_snow_joined_ts 
WHERE traffic_precipitation_joined_ts.SegmentID = traffic_snow_joined_ts.SegmentID INTO {} STORED AS PARQUET
""".format(traffic_ts_join_precipitation_ts_location, traffic_ts_join_snow_ts_location, targeturl)
join_all_ts_jobId = sqlClient.submit_sql(join_all_ts_sql)
job_status = sqlClient.wait_for_job(join_all_ts_jobId)
join_all_ts_location = sqlClient.get_job(join_all_ts_jobId)['resultset_location']

# %% [markdown]
# **(9) Explode Temporally Joined Series in step (8) and select the road segment identifier, congestion and weather features for each timestamp ordered by the (identifier, timestamp) to get the final set of features to train the machine learning model**: Finally, we explode the previously joined timeseries to get the joined traffic congestion and weather features.

# %%
features_sql = """
WITH joined_exploded AS
		(SELECT SegmentID,
				TS_DA_EXPLODE(joined_ts) AS (TIMESTAMP,value)
			FROM {} STORED AS PARQUET AS traffic_weather_joined_ts)
SELECT SegmentID,
	TIMESTAMP,
	value[0] AS congestion,
	value[1] AS precipitation,
	value[2] AS snow
FROM joined_exploded
ORDER BY SegmentID,
	TIMESTAMP
INTO {}
""".format(join_all_ts_location, targeturl + "_train_features")
features = sqlClient.run_sql(features_sql)
if isinstance(features, str):
    print(features)

# %%
features.head(10)
# Out:
#    SegmentID      TIMESTAMP  congestion  precipitation  snow
# 0          1  1522540866000    0.833333            0.0   0.0
# 1          1  1522542038000    0.833333            0.0   0.0
# 2          1  1522543205000    0.966667            0.0   0.0
# 3          1  1522546806000    0.833333            0.0   0.0
# 4          1  1522547416000    0.966667            0.0   0.0
# 5          1  1522548619000    0.833333            0.0   0.0
# 6          1  1522549238000    0.900000            0.0   0.0
# 7          1  1522549849000    0.833333            0.0   0.0
# 8          1  1522559416000    1.033333            0.0   0.0
# 9          1  1522561202000    1.066667            0.0   0.0

# %% [markdown]
# ### <a name="compoundetl"></a> 4. Compound ETL
# For efficiency reasons, instead of running step by step ETL statements and storing and retrieving intermediate results from COS, we can directly run our entire ETL pipeline in a single SQL query. We will look at how to do that in this section. You can skip running the cell in this section if you have already run the cells in the previous section.

# %%
compound_etl_sql = """
-- ### (1) JOIN TRAFFIC AND WEATHER METADATA IDENTIFIERS: WE FIRST SUB-SELECT SEGMENT LOCATIONS IN DOWNTOWN CHICAGO THROUGH A ST_CONTAINS SPATIAL 
    -- OPERATION. WE THEN PERFORM A SPATIAL DISTANCE BASED CROSS JOIN BETWEEN THE SUB-SELECTED SEGMENT LOCATIONS AND THE WEATHER SITE LOCATIONS AND PICK 
    -- THE CLOSEST DISTANCE PAIRS TO OBTAIN CORRESPONDING WEATHER SITE IDS FOR EVERY SEGMENT ID. ###
WITH
    metadata AS (SELECT SegmentID, SiteId
                    FROM
                (
                SELECT *, dense_rank() over (partition by SegmentID order by dist asc) as rank
                    FROM
                (
                SELECT SegmentID, SiteId, ST_Distance(Segment, ST_Point(Longitude, Latitude)) as dist 
                    FROM cos://us-geo/sql/weather_sites.parquet STORED AS PARQUET 
                    CROSS JOIN (SELECT SegmentID, Segment FROM cos://us-east/mytestbucket123/segment_locations.parquet STORED AS PARQUET
                    WHERE ST_Contains(ST_WKTToSQL('POLYGON((-87.66182361726857 42.013649516597454,-87.78404651765919 42.00956804496257,-87.78541980867482 41.90335786993515,-87.71126209383107 41.74268615114427,-87.61513172273732 41.71296382783499,-87.54784046297169 41.746784702779486,-87.61650501375294 41.86246067685847,-87.66182361726857 42.013649516597454))'), Segment))
                )
                )
                WHERE rank <= 1
                ),
    -- ### (2) CREATE TRAFFIC TIMESERIES: WE CREATE PER- ROAD SEGMENT TRAFFIC CONGESTION TIMESERIES USING THE TIME_SERIES FUNCTION. ###
    traffic_ts AS (SELECT SegmentID, TIME_SERIES(TS_TIMESTAMP(to_timestamp(TIME, "MM/dd/yyyy hh:mm:ss aaa")), speed/30) AS ts
                          FROM cos://us-geo/sql/traffic.parquet STORED AS PARQUET
                          WHERE speed >= 0
                          GROUP BY SegmentID),
    -- ### (3) CREATE A PER- WEATHER SITE TIMESERIES FOR PRECIPITATION VALUES USING THE TIME_SERIES FUNCTION. ###
    precipitation_ts AS (SELECT SiteId, TIME_SERIES(TS_TIMESTAMP(to_timestamp(DateHrGmt, "MM/dd/yyyy HH:mm:ss")), PrecipitationPreviousHourInches) AS ts
                          FROM cos://us-geo/sql/weather.parquet STORED AS PARQUET
                          GROUP BY SiteId),
    -- ### (4) CREATE A PER- WEATHER SITE TIMESERIES FOR SNOW VALUES USING THE TIME_SERIES FUNCTION. ###
    snow_ts AS (SELECT SiteId, TIME_SERIES(TS_TIMESTAMP(to_timestamp(DateHrGmt, "MM/dd/yyyy HH:mm:ss")), SnowfallInches) AS ts
                          FROM cos://us-geo/sql/weather.parquet STORED AS PARQUET
                          GROUP BY SiteId),
    -- ### (5) JOIN THE TRAFFIC CONGESTION TIMESERIES WITH THE METADATA OBTAINED IN STEP (1), SO THAT WE HAVE CLOSEST SITE ID FOR EVERY SEGMENT ID. ### 
    id_joined_traffic_ts AS (SELECT traffic_ts.SegmentID, traffic_ts.ts, metadata.SiteId FROM metadata, traffic_ts 
                             WHERE traffic_ts.SegmentID = metadata.SegmentID),
    -- ### (6) JOIN THE TRAFFIC CONGESTION TIMESERIES WITH THE PRECIPITATION TIMESERIES USING THE TS_LEFT_JOIN FUNCTION. ###
    traffic_precipitation_joined_ts AS (SELECT SegmentID, precipitation_ts.SiteId, 
                                                TS_LEFT_JOIN(id_joined_traffic_ts.ts, precipitation_ts.ts, TS_INTERPOLATOR_PREV(0.0)) as ts1_ts2
                                        FROM id_joined_traffic_ts, precipitation_ts
                                        WHERE id_joined_traffic_ts.SiteId = precipitation_ts.SiteId),
    -- ### (7) JOIN THE TRAFFIC CONGESTION TIMESERIES WITH THE SNOW TIMESERIES USING THE TS_LEFT_JOIN FUNCTION. ###
    traffic_snow_joined_ts AS (SELECT SegmentID, snow_ts.SiteId, 
                                    TS_LEFT_JOIN(id_joined_traffic_ts.ts, snow_ts.ts, TS_INTERPOLATOR_PREV(0.0)) as ts1_ts2
                                FROM id_joined_traffic_ts, snow_ts
                                WHERE id_joined_traffic_ts.SiteId = snow_ts.SiteId),
    -- ### (8) JOIN THE TRAFFIC CONGESTION, PRECIPITATION AND SNOW TIMESERIES TOGETHER. ###
    traffic_weather_joined_ts AS (SELECT traffic_precipitation_joined_ts.SegmentID, 
                                    TS_VECTOR3(TS_INDEX(traffic_precipitation_joined_ts.ts1_ts2, 0), 
                                                TS_INDEX(traffic_precipitation_joined_ts.ts1_ts2, 1), 
                                                TS_INDEX(traffic_snow_joined_ts.ts1_ts2, 1)) AS joined_ts 
                                FROM traffic_precipitation_joined_ts, traffic_snow_joined_ts 
                                WHERE traffic_precipitation_joined_ts.SegmentID = traffic_snow_joined_ts.SegmentID),
    -- ### (9) EXPLODE THE PREVIOUSLY JOINED TIMESERIES TO GET THE JOINED CONGESTION AND WEATHER FEATURES. ###
    joined_exploded AS (SELECT SegmentID, TS_DA_EXPLODE(joined_ts) AS (timestamp, value)
                        FROM traffic_weather_joined_ts)
SELECT SegmentID, timestamp, value[0] AS congestion, value[1] AS precipitation, value[2] as snow FROM joined_exploded order by SegmentID, timestamp
INTO {}
""".format(targeturl + "_train_features")
features = sqlClient.run_sql(compound_etl_sql)
if isinstance(features, str):
    print(features)
features.head(10)
# Out:
#    SegmentID      timestamp  congestion  precipitation  snow
# 0         37  1522962067000    0.833333          0.001   0.0
# 1         37  1522962620000    0.666667          0.001   0.0
# 2         37  1522963237000    0.900000          0.001   0.0
# 3         37  1522963853000    0.633333          0.001   0.0
# 4         37  1522965019000    0.766667          0.001   0.0
# 5         37  1522965670000    0.600000          0.001   0.0
# 6         37  1522966220000    0.700000          0.001   0.0
# 7         37  1522966836000    0.666667          0.001   0.0
# 8         37  1522967450000    0.733333          0.001   0.0
# 9         37  1522968618000    0.633333          0.001   0.0

# %% [markdown]
# ### <a name="train"></a> 5. Machine Learning Model Training

# %% [markdown]
# We now have all the required data features per-road segment, per-timestamp needed to train our predictive model, in the 'features' dataframe. Next, we will group these congestion and weather features by road segment identifiers, so that we can create per-road segment models. Specifically, we will develop regression tree models for each road segment using the scikit-learn package. The training involves regressing on the traffic congestion and weather condition values to predict the traffic congestion at the next timestep (since we have a sampling rate of 10 minutes, next (predicted) timestep will be 10 minutes ahead).

# %%
all_models = {}
grouped = features.groupby('SegmentID')
# Loop through all road segments one by one, since we need to create one model for each road segment
for name, group in grouped:
    x = []
    y = []
    # For each road segment, create data instances to train a regression tree, by looping through every 10 minute sample
    for i in range(0, group.shape[0] - 1):
        prev_congestion = group.iloc[i]['congestion']
        snow = group.iloc[i]['snow']
        precip = group.iloc[i]['precipitation']
        predict_congestion = group.iloc[i+1]['congestion']
        x.append([prev_congestion, snow, precip])
        y.append(predict_congestion)
    clf = tree.tree.DecisionTreeRegressor()
    if len(x) > 0:
        clf = clf.fit(x, y)
        all_models[name] = clf

# %% [markdown]
# In the cell above, we created per-road segment predictive models. These are stored in the 'all_models' dictionary keyed by the road segment identifier, so that we can use them to predict traffic congestion later.

# %% [markdown]
# ### <a name="prediction"></a> 6. Traffic Congestion Prediction

# %% [markdown]
# Now that we have trained machine learning models to predict traffic congestion on road segments, we can use them to predict congestion in real-time based on the traffic and weather conditions.
# For simplicity, in this notebook, we will show a single prediction at the next time step, i.e, for each road segment, we will use the available traffic congestion and weather attributes from the last timestep in 'features' as inputs and predict congestion at the next timestep

# %%
# Add last timestep traffic congestion and weather values as input values to be used for prediction
to_predict = {}
for name, group in grouped:
    last_timestep = group.shape[0] - 1
    to_predict[name] = [[group.iloc[last_timestep]['congestion'], group.iloc[last_timestep]['snow'], group.iloc[last_timestep]['precipitation']]]
# Get the per road segment predictions using inputs in 'to_predict' and also store them in a dictionary
predicted = {}
for val in to_predict:
    if val in all_models:
        pred_congestion = all_models[val].predict(to_predict[val])
        predicted[val] = pred_congestion
        print('Predicted congestion for segment ' + str(val) + " = " + str(pred_congestion[0]))
# Out:
# Predicted congestion for segment 1 = 0.729166666667
# Predicted congestion for segment 2 = 0.766666666667
# Predicted congestion for segment 3 = 0.73567251462
# Predicted congestion for segment 4 = 0.704301075269
# Predicted congestion for segment 5 = 0.913402061856
# Predicted congestion for segment 6 = 0.696396396396
# Predicted congestion for segment 7 = 0.71875
# Predicted congestion for segment 8 = 0.71746031746
# Predicted congestion for segment 9 = 0.98115942029
# Predicted congestion for segment 10 = 0.746846846847
# Predicted congestion for segment 11 = 0.792063492063
# Predicted congestion for segment 29 = 0.75
# Predicted congestion for segment 30 = 0.849450549451
# Predicted congestion for segment 31 = 0.789523809524
# Predicted congestion for segment 32 = 0.72697495183
# Predicted congestion for segment 33 = 0.782777777778
# Predicted congestion for segment 34 = 0.878395061728
# Predicted congestion for segment 35 = 0.896875
# Predicted congestion for segment 36 = 1.02276422764
# Predicted congestion for segment 37 = 0.723516720604
# Predicted congestion for segment 38 = 0.755128205128
# Predicted congestion for segment 39 = 0.770503597122
# Predicted congestion for segment 40 = 0.71975308642
# Predicted congestion for segment 41 = 0.776923076923
# Predicted congestion for segment 42 = 0.621264367816
# Predicted congestion for segment 43 = 0.775757575758
# Predicted congestion for segment 44 = 0.832128514056
# Predicted congestion for segment 45 = 0.672222222222
# Predicted congestion for segment 46 = 0.530612244898
# Predicted congestion for segment 47 = 0.664583333333
# Predicted congestion for segment 48 = 0.747747747748
# Predicted congestion for segment 49 = 0.688771929825
# Predicted congestion for segment 50 = 0.719475655431
# Predicted congestion for segment 51 = 0.674545454545
# Predicted congestion for segment 52 = 0.805392156863
# Predicted congestion for segment 53 = 0.922222222222
# Predicted congestion for segment 54 = 0.705797101449
# Predicted congestion for segment 55 = 0.642748091603
# Predicted congestion for segment 56 = 1.02
# Predicted congestion for segment 57 = 0.966666666667
# Predicted congestion for segment 69 = 0.771604938272
# Predicted congestion for segment 70 = 0.78253968254
# Predicted congestion for segment 71 = 0.8375
# Predicted congestion for segment 72 = 0.740568475452
# Predicted congestion for segment 73 = 0.783333333333
# Predicted congestion for segment 74 = 0.810416666667
# Predicted congestion for segment 75 = 0.941942604857
# Predicted congestion for segment 76 = 0.945698924731
# Predicted congestion for segment 77 = 0.770512820513
# Predicted congestion for segment 78 = 0.628571428571
# Predicted congestion for segment 79 = 0.6874617737
# Predicted congestion for segment 80 = 0.627333333333
# Predicted congestion for segment 81 = 0.697916666667
# Predicted congestion for segment 82 = 0.681609195402
# Predicted congestion for segment 83 = 0.632380952381
# Predicted congestion for segment 84 = 0.786885245902
# Predicted congestion for segment 85 = 1.0
# Predicted congestion for segment 86 = 0.740310077519
# Predicted congestion for segment 87 = 0.757692307692
# Predicted congestion for segment 88 = 0.650256410256
# Predicted congestion for segment 89 = 0.604504504505
# Predicted congestion for segment 90 = 0.815196078431
# Predicted congestion for segment 91 = 0.694594594595
# Predicted congestion for segment 92 = 0.710256410256
# Predicted congestion for segment 93 = 0.69390070922
# Predicted congestion for segment 94 = 0.678231292517
# Predicted congestion for segment 95 = 0.628125
# Predicted congestion for segment 96 = 0.96546184739
# Predicted congestion for segment 97 = 0.825465838509
# Predicted congestion for segment 99 = 0.761561561562
# Predicted congestion for segment 100 = 0.777441077441
# Predicted congestion for segment 101 = 0.77619047619
# Predicted congestion for segment 102 = 0.925683060109
# Predicted congestion for segment 103 = 0.750980392157
# Predicted congestion for segment 104 = 0.848765432099
# Predicted congestion for segment 105 = 0.925423728814
# Predicted congestion for segment 106 = 0.873333333333
# Predicted congestion for segment 107 = 0.8
# Predicted congestion for segment 108 = 0.748924731183
# Predicted congestion for segment 109 = 0.760236886633
# Predicted congestion for segment 110 = 0.878456014363
# Predicted congestion for segment 111 = 0.870175438596
# Predicted congestion for segment 112 = 0.773846153846
# Predicted congestion for segment 113 = 0.940740740741
# Predicted congestion for segment 114 = 0.664761904762
# Predicted congestion for segment 115 = 0.759027777778
# Predicted congestion for segment 116 = 0.668888888889
# Predicted congestion for segment 117 = 0.716425120773
# Predicted congestion for segment 118 = 0.770440251572
# Predicted congestion for segment 119 = 0.713811420983
# Predicted congestion for segment 120 = 0.670731707317
# Predicted congestion for segment 121 = 0.715476190476
# Predicted congestion for segment 122 = 0.628571428571
# Predicted congestion for segment 123 = 0.718018018018
# Predicted congestion for segment 124 = 0.766666666667
# Predicted congestion for segment 125 = 0.615800865801
# Predicted congestion for segment 126 = 0.772807017544
# Predicted congestion for segment 127 = 0.778927203065
# Predicted congestion for segment 129 = 0.711111111111
# Predicted congestion for segment 131 = 0.757516339869
# Predicted congestion for segment 132 = 0.612121212121
# Predicted congestion for segment 134 = 0.763670411985
# Predicted congestion for segment 135 = 0.76358974359
# Predicted congestion for segment 136 = 0.826126126126
# Predicted congestion for segment 137 = 0.922222222222
# Predicted congestion for segment 138 = 0.738676844784
# Predicted congestion for segment 139 = 0.795024875622
# Predicted congestion for segment 140 = 0.845333333333
# Predicted congestion for segment 141 = 0.830303030303
# Predicted congestion for segment 142 = 0.820833333333
# Predicted congestion for segment 143 = 0.783703703704
# Predicted congestion for segment 144 = 0.806060606061
# Predicted congestion for segment 145 = 0.86455399061
# Predicted congestion for segment 146 = 0.771527777778
# Predicted congestion for segment 147 = 0.86866359447
# Predicted congestion for segment 148 = 0.957644110276
# Predicted congestion for segment 149 = 0.652592592593
# Predicted congestion for segment 150 = 0.838262910798
# Predicted congestion for segment 151 = 0.6
# Predicted congestion for segment 152 = 0.677683615819
# Predicted congestion for segment 153 = 0.838888888889
# Predicted congestion for segment 154 = 0.685585585586
# Predicted congestion for segment 155 = 0.696090534979
# Predicted congestion for segment 156 = 0.697101449275
# Predicted congestion for segment 157 = 0.770048309179
# Predicted congestion for segment 158 = 0.736124031008
# Predicted congestion for segment 159 = 0.711111111111
# Predicted congestion for segment 160 = 0.793939393939
# Predicted congestion for segment 161 = 0.670802919708
# Predicted congestion for segment 162 = 0.742296918768
# Predicted congestion for segment 166 = 0.726016260163
# Predicted congestion for segment 170 = 0.782083333333
# Predicted congestion for segment 171 = 0.815032679739
# Predicted congestion for segment 172 = 0.787288135593
# Predicted congestion for segment 173 = 0.713227513228
# Predicted congestion for segment 174 = 0.735416666667
# Predicted congestion for segment 175 = 0.999598393574
# Predicted congestion for segment 176 = 0.75875
# Predicted congestion for segment 177 = 0.770222222222
# Predicted congestion for segment 178 = 0.774774774775
# Predicted congestion for segment 179 = 0.914141414141
# Predicted congestion for segment 180 = 0.655505952381
# Predicted congestion for segment 181 = 0.708812260536
# Predicted congestion for segment 186 = 0.704761904762
# Predicted congestion for segment 187 = 0.69696969697
# Predicted congestion for segment 188 = 0.693693693694
# Predicted congestion for segment 189 = 0.683333333333
# Predicted congestion for segment 190 = 0.716666666667
# Predicted congestion for segment 191 = 0.635964912281
# Predicted congestion for segment 192 = 0.633333333333
# Predicted congestion for segment 193 = 0.647619047619
# Predicted congestion for segment 194 = 0.727659574468
# Predicted congestion for segment 195 = 0.717013888889
# Predicted congestion for segment 198 = 0.788262910798
# Predicted congestion for segment 199 = 0.699645390071
# Predicted congestion for segment 200 = 0.765811965812
# Predicted congestion for segment 201 = 0.770464135021
# Predicted congestion for segment 202 = 0.678006872852
# Predicted congestion for segment 203 = 0.663421828909
# Predicted congestion for segment 204 = 0.660897435897
# Predicted congestion for segment 205 = 0.623777777778
# Predicted congestion for segment 206 = 0.712564102564
# Predicted congestion for segment 207 = 0.711666666667
# Predicted congestion for segment 208 = 0.636842105263
# Predicted congestion for segment 209 = 0.608974358974
# Predicted congestion for segment 210 = 0.646566164154
# Predicted congestion for segment 211 = 0.708176100629
# Predicted congestion for segment 212 = 0.785950413223
# Predicted congestion for segment 214 = 0.973263888889
# Predicted congestion for segment 215 = 0.912777777778
# Predicted congestion for segment 216 = 0.9
# Predicted congestion for segment 217 = 0.721212121212
# Predicted congestion for segment 218 = 0.761111111111
# Predicted congestion for segment 219 = 0.598697916667
# Predicted congestion for segment 220 = 0.693548387097
# Predicted congestion for segment 221 = 0.90303030303
# Predicted congestion for segment 222 = 0.675953565506
# Predicted congestion for segment 223 = 0.772222222222
# Predicted congestion for segment 224 = 0.73835978836
# Predicted congestion for segment 225 = 0.577564102564
# Predicted congestion for segment 226 = 0.611784511785
# Predicted congestion for segment 227 = 0.789115646259
# Predicted congestion for segment 228 = 0.550877192982
# Predicted congestion for segment 230 = 1.00797101449
# Predicted congestion for segment 231 = 0.90101010101
# Predicted congestion for segment 232 = 0.977304964539
# Predicted congestion for segment 233 = 0.779365079365
# Predicted congestion for segment 234 = 0.777272727273
# Predicted congestion for segment 235 = 0.741025641026
# Predicted congestion for segment 236 = 0.623611111111
# Predicted congestion for segment 237 = 0.955555555556
# Predicted congestion for segment 238 = 0.640360046458
# Predicted congestion for segment 239 = 0.792523364486
# Predicted congestion for segment 240 = 0.652208835341
# Predicted congestion for segment 241 = 0.738461538462
# Predicted congestion for segment 242 = 0.640425531915
# Predicted congestion for segment 243 = 0.625490196078
# Predicted congestion for segment 244 = 0.568229166667
# Predicted congestion for segment 252 = 0.777894736842
# Predicted congestion for segment 255 = 1.45555555556
# Predicted congestion for segment 256 = 0.755630630631
# Predicted congestion for segment 257 = 0.735087719298
# Predicted congestion for segment 258 = 0.6625
# Predicted congestion for segment 259 = 0.8
# Predicted congestion for segment 260 = 0.735378323108
# Predicted congestion for segment 261 = 0.692957746479
# Predicted congestion for segment 262 = 0.684057971014
# Predicted congestion for segment 263 = 0.801418439716
# Predicted congestion for segment 270 = 1.11111111111
# Predicted congestion for segment 271 = 0.734513274336
# Predicted congestion for segment 272 = 0.714285714286
# Predicted congestion for segment 273 = 0.813580246914
# Predicted congestion for segment 274 = 0.84465408805
# Predicted congestion for segment 275 = 0.647422680412
# Predicted congestion for segment 276 = 0.67619047619
# Predicted congestion for segment 277 = 0.832116788321
# Predicted congestion for segment 278 = 0.696846846847
# Predicted congestion for segment 284 = 0.671428571429
# Predicted congestion for segment 285 = 0.686005089059
# Predicted congestion for segment 286 = 0.613333333333
# Predicted congestion for segment 287 = 0.726724137931
# Predicted congestion for segment 288 = 0.671025641026
# Predicted congestion for segment 289 = 0.727737226277
# Predicted congestion for segment 290 = 0.691875
# Predicted congestion for segment 291 = 0.625541125541
# Predicted congestion for segment 292 = 0.702222222222
# Predicted congestion for segment 293 = 0.66394129979
# Predicted congestion for segment 294 = 0.641489361702
# Predicted congestion for segment 295 = 0.69512195122
# Predicted congestion for segment 296 = 0.818518518519
# Predicted congestion for segment 297 = 0.568771929825
# Predicted congestion for segment 298 = 0.584905660377
# Predicted congestion for segment 305 = 0.747094801223
# Predicted congestion for segment 306 = 0.644444444444
# Predicted congestion for segment 307 = 0.747572815534
# Predicted congestion for segment 308 = 0.670138888889
# Predicted congestion for segment 309 = 0.672727272727
# Predicted congestion for segment 310 = 0.671895424837
# Predicted congestion for segment 311 = 0.689516129032
# Predicted congestion for segment 312 = 0.639393939394
# Predicted congestion for segment 313 = 0.756488549618
# Predicted congestion for segment 314 = 0.692873563218
# Predicted congestion for segment 315 = 0.677099236641
# Predicted congestion for segment 316 = 0.655380577428
# Predicted congestion for segment 317 = 0.770646766169
# Predicted congestion for segment 318 = 0.724712643678
# Predicted congestion for segment 319 = 0.561904761905
# Predicted congestion for segment 322 = 0.881818181818
# Predicted congestion for segment 323 = 0.8
# Predicted congestion for segment 324 = 0.652732240437
# Predicted congestion for segment 325 = 0.728516377649
# Predicted congestion for segment 326 = 0.765882352941
# Predicted congestion for segment 333 = 0.833333333333
# Predicted congestion for segment 334 = 0.833333333333
# Predicted congestion for segment 335 = 0.868974358974
# Predicted congestion for segment 336 = 0.869005847953
# Predicted congestion for segment 337 = 0.831899641577
# Predicted congestion for segment 338 = 0.77197640118
# Predicted congestion for segment 339 = 0.738797814208
# Predicted congestion for segment 340 = 0.877866666667
# Predicted congestion for segment 341 = 0.938805970149
# Predicted congestion for segment 342 = 0.830620155039
# Predicted congestion for segment 343 = 0.919270833333
# Predicted congestion for segment 344 = 0.957333333333
# Predicted congestion for segment 345 = 0.773993207181
# Predicted congestion for segment 346 = 0.911337868481
# Predicted congestion for segment 347 = 0.87519379845
# Predicted congestion for segment 348 = 0.858333333333
# Predicted congestion for segment 349 = 0.850282485876
# Predicted congestion for segment 350 = 0.864516129032
# Predicted congestion for segment 351 = 0.879166666667
# Predicted congestion for segment 352 = 0.824637681159
# Predicted congestion for segment 353 = 0.854385964912
# Predicted congestion for segment 354 = 0.733333333333
# Predicted congestion for segment 355 = 0.776094276094
# Predicted congestion for segment 356 = 0.771428571429
# Predicted congestion for segment 357 = 0.854954954955
# Predicted congestion for segment 358 = 0.619119496855
# Predicted congestion for segment 359 = 0.659484346225
# Predicted congestion for segment 360 = 0.956666666667
# Predicted congestion for segment 361 = 0.826666666667
# Predicted congestion for segment 362 = 0.75534591195
# Predicted congestion for segment 363 = 0.812165450122
# Predicted congestion for segment 364 = 0.694285714286
# Predicted congestion for segment 365 = 0.8625
# Predicted congestion for segment 366 = 0.992753623188
# Predicted congestion for segment 367 = 1.03333333333
# Predicted congestion for segment 374 = 1.02222222222
# Predicted congestion for segment 375 = 0.857142857143
# Predicted congestion for segment 376 = 0.977519379845
# Predicted congestion for segment 377 = 0.855981182796
# Predicted congestion for segment 378 = 0.803603603604
# Predicted congestion for segment 379 = 0.823611111111
# Predicted congestion for segment 380 = 0.93125
# Predicted congestion for segment 381 = 0.911752136752
# Predicted congestion for segment 382 = 0.664444444444
# Predicted congestion for segment 383 = 0.642937853107
# Predicted congestion for segment 384 = 0.799290780142
# Predicted congestion for segment 385 = 1.00092592593
# Predicted congestion for segment 386 = 0.741604938272
# Predicted congestion for segment 387 = 0.961728395062
# Predicted congestion for segment 388 = 0.893554327808
# Predicted congestion for segment 389 = 0.780597014925
# Predicted congestion for segment 390 = 0.847400611621
# Predicted congestion for segment 391 = 0.737164750958
# Predicted congestion for segment 392 = 0.679951690821
# Predicted congestion for segment 393 = 0.817417417417
# Predicted congestion for segment 394 = 0.92303030303
# Predicted congestion for segment 395 = 0.667479674797
# Predicted congestion for segment 396 = 0.664814814815
# Predicted congestion for segment 397 = 0.752857142857
# Predicted congestion for segment 398 = 0.771232876712
# Predicted congestion for segment 399 = 0.70431372549
# Predicted congestion for segment 400 = 0.619393939394
# Predicted congestion for segment 401 = 0.920833333333
# Predicted congestion for segment 402 = 0.710382513661
# Predicted congestion for segment 403 = 0.793660531697
# Predicted congestion for segment 404 = 0.866336633663
# Predicted congestion for segment 405 = 0.703389830508
# Predicted congestion for segment 406 = 0.838793103448
# Predicted congestion for segment 407 = 0.943209876543
# Predicted congestion for segment 408 = 0.887064676617
# Predicted congestion for segment 409 = 0.714794007491
# Predicted congestion for segment 410 = 0.665917602996
# Predicted congestion for segment 411 = 0.651777777778
# Predicted congestion for segment 412 = 0.564545454545
# Predicted congestion for segment 413 = 0.764197530864
# Predicted congestion for segment 414 = 0.74811827957
# Predicted congestion for segment 418 = 0.861728395062
# Predicted congestion for segment 419 = 0.761538461538
# Predicted congestion for segment 420 = 0.610588235294
# Predicted congestion for segment 421 = 0.675956284153
# Predicted congestion for segment 422 = 0.6875
# Predicted congestion for segment 423 = 0.78547008547
# Predicted congestion for segment 429 = 0.764157706093
# Predicted congestion for segment 430 = 0.944298245614
# Predicted congestion for segment 442 = 0.889130434783
# Predicted congestion for segment 443 = 0.933333333333
# Predicted congestion for segment 444 = 0.728472222222
# Predicted congestion for segment 445 = 0.966666666667
# Predicted congestion for segment 446 = 0.57037037037
# Predicted congestion for segment 447 = 0.741666666667
# Predicted congestion for segment 448 = 0.608212560386
# Predicted congestion for segment 449 = 1.05844155844
# Predicted congestion for segment 450 = 0.633333333333
# Predicted congestion for segment 451 = 0.817857142857
# Predicted congestion for segment 452 = 0.733333333333
# Predicted congestion for segment 453 = 0.635050071531
# Predicted congestion for segment 454 = 0.53619047619
# Predicted congestion for segment 455 = 0.665668662675
# Predicted congestion for segment 456 = 1.0025974026
# Predicted congestion for segment 468 = 0.787919463087
# Predicted congestion for segment 469 = 0.962962962963
# Predicted congestion for segment 470 = 0.960576923077
# Predicted congestion for segment 498 = 0.650967741935
# Predicted congestion for segment 499 = 0.926666666667
# Predicted congestion for segment 500 = 0.946086956522
# Predicted congestion for segment 501 = 0.731481481481
# Predicted congestion for segment 502 = 0.839233038348
# Predicted congestion for segment 503 = 0.824369747899
# Predicted congestion for segment 504 = 0.911111111111
# Predicted congestion for segment 505 = 0.845631067961
# Predicted congestion for segment 506 = 0.96049382716
# Predicted congestion for segment 513 = 0.796799116998
# Predicted congestion for segment 514 = 0.911728395062
# Predicted congestion for segment 515 = 0.897126436782
# Predicted congestion for segment 516 = 0.797076023392
# Predicted congestion for segment 517 = 0.8836996337
# Predicted congestion for segment 518 = 0.580092592593
# Predicted congestion for segment 519 = 0.788888888889
# Predicted congestion for segment 520 = 0.753333333333
# Predicted congestion for segment 521 = 0.98
# Predicted congestion for segment 525 = 0.823687423687
# Predicted congestion for segment 526 = 0.99918699187
# Predicted congestion for segment 528 = 1.02988505747
# Predicted congestion for segment 529 = 0.750617283951
# Predicted congestion for segment 530 = 0.966666666667
# Predicted congestion for segment 531 = 1.06666666667
# Predicted congestion for segment 532 = 0.787234042553
# Predicted congestion for segment 533 = 0.783333333333
# Predicted congestion for segment 534 = 0.656396396396
# Predicted congestion for segment 535 = 0.680952380952
# Predicted congestion for segment 536 = 0.584615384615
# Predicted congestion for segment 537 = 0.6328
# Predicted congestion for segment 538 = 0.629824561404
# Predicted congestion for segment 539 = 0.606666666667
# Predicted congestion for segment 540 = 0.754696969697
# Predicted congestion for segment 541 = 0.697619047619
# Predicted congestion for segment 542 = 0.835585585586
# Predicted congestion for segment 543 = 0.588888888889
# Predicted congestion for segment 544 = 0.697736625514
# Predicted congestion for segment 545 = 0.59
# Predicted congestion for segment 546 = 0.850314465409
# Predicted congestion for segment 547 = 0.795286195286
# Predicted congestion for segment 548 = 0.698048780488
# Predicted congestion for segment 549 = 0.661904761905
# Predicted congestion for segment 550 = 0.702577319588
# Predicted congestion for segment 551 = 0.570512820513
# Predicted congestion for segment 552 = 0.687254901961
# Predicted congestion for segment 553 = 0.669696969697
# Predicted congestion for segment 554 = 0.682828282828
# Predicted congestion for segment 555 = 0.715111111111
# Predicted congestion for segment 556 = 0.728431372549
# Predicted congestion for segment 557 = 0.858747697974
# Predicted congestion for segment 558 = 0.741767068273
# Predicted congestion for segment 559 = 0.598039215686
# Predicted congestion for segment 560 = 0.496078431373
# Predicted congestion for segment 571 = 0.818803418803
# Predicted congestion for segment 572 = 0.658333333333
# Predicted congestion for segment 573 = 0.702083333333
# Predicted congestion for segment 574 = 0.709950248756
# Predicted congestion for segment 575 = 0.772222222222
# Predicted congestion for segment 576 = 0.8625
# Predicted congestion for segment 577 = 0.722442244224
# Predicted congestion for segment 578 = 1.75443526171
# Predicted congestion for segment 579 = 1.82038791159
# Predicted congestion for segment 580 = 1.70492307692
# Predicted congestion for segment 581 = 1.8161849711
# Predicted congestion for segment 582 = 1.69317073171
# Predicted congestion for segment 583 = 1.40564102564
# Predicted congestion for segment 598 = 1.43537953795
# Predicted congestion for segment 604 = 0.990340459224
# Predicted congestion for segment 605 = 1.6239511823
# Predicted congestion for segment 606 = 1.59479479479
# Predicted congestion for segment 607 = 1.66333333333
# Predicted congestion for segment 608 = 1.79216566866
# Predicted congestion for segment 609 = 1.69666666667
# Predicted congestion for segment 610 = 1.81666666667
# Predicted congestion for segment 611 = 1.77580645161
# Predicted congestion for segment 612 = 1.5
# Predicted congestion for segment 623 = 0.790633608815
# Predicted congestion for segment 624 = 0.645238095238
# Predicted congestion for segment 625 = 0.777450980392
# Predicted congestion for segment 626 = 0.833333333333
# Predicted congestion for segment 627 = 0.788888888889
# Predicted congestion for segment 628 = 0.833333333333
# Predicted congestion for segment 629 = 0.842528735632
# Predicted congestion for segment 640 = 0.772303921569
# Predicted congestion for segment 641 = 0.820833333333
# Predicted congestion for segment 642 = 0.663209876543
# Predicted congestion for segment 643 = 0.644210526316
# Predicted congestion for segment 644 = 0.805448717949
# Predicted congestion for segment 645 = 0.75
# Predicted congestion for segment 646 = 0.748484848485
# Predicted congestion for segment 647 = 0.727777777778
# Predicted congestion for segment 648 = 0.664423076923
# Predicted congestion for segment 649 = 0.730952380952
# Predicted congestion for segment 650 = 0.729487179487
# Predicted congestion for segment 651 = 0.752
# Predicted congestion for segment 652 = 0.747429519071
# Predicted congestion for segment 653 = 0.815555555556
# Predicted congestion for segment 656 = 0.533333333333
# Predicted congestion for segment 660 = 0.511746031746
# Predicted congestion for segment 674 = 0.533333333333
# Predicted congestion for segment 679 = 0.676149425287
# Predicted congestion for segment 680 = 0.718181818182
# Predicted congestion for segment 683 = 0.869444444444
# Predicted congestion for segment 684 = 0.851282051282
# Predicted congestion for segment 685 = 0.814521452145
# Predicted congestion for segment 686 = 0.756172839506
# Predicted congestion for segment 687 = 0.781132075472
# Predicted congestion for segment 688 = 0.735353535354
# Predicted congestion for segment 689 = 0.689156626506
# Predicted congestion for segment 690 = 0.690514905149
# Predicted congestion for segment 691 = 0.693162393162
# Predicted congestion for segment 692 = 0.795833333333
# Predicted congestion for segment 693 = 0.65
# Predicted congestion for segment 694 = 0.763492063492
# Predicted congestion for segment 695 = 0.846474358974
# Predicted congestion for segment 696 = 0.738738738739
# Predicted congestion for segment 697 = 0.806535947712
# Predicted congestion for segment 698 = 0.683333333333
# Predicted congestion for segment 699 = 0.687719298246
# Predicted congestion for segment 700 = 0.646931407942
# Predicted congestion for segment 702 = 0.885648148148
# Predicted congestion for segment 703 = 0.778385416667
# Predicted congestion for segment 704 = 0.895072463768
# Predicted congestion for segment 705 = 0.814444444444
# Predicted congestion for segment 706 = 0.805813953488
# Predicted congestion for segment 707 = 0.795597484277
# Predicted congestion for segment 708 = 0.80404040404
# Predicted congestion for segment 709 = 0.724324324324
# Predicted congestion for segment 710 = 0.662222222222
# Predicted congestion for segment 711 = 0.802259887006
# Predicted congestion for segment 712 = 0.779111111111
# Predicted congestion for segment 713 = 0.844186046512
# Predicted congestion for segment 714 = 0.816666666667
# Predicted congestion for segment 715 = 0.75
# Predicted congestion for segment 716 = 1.0
# Predicted congestion for segment 717 = 0.750952380952
# Predicted congestion for segment 718 = 0.7625
# Predicted congestion for segment 719 = 0.726936026936
# Predicted congestion for segment 721 = 1.12
# Predicted congestion for segment 737 = 0.729090909091
# Predicted congestion for segment 738 = 0.665151515152
# Predicted congestion for segment 739 = 0.661240310078
# Predicted congestion for segment 757 = 0.487407407407
# Predicted congestion for segment 772 = 0.733333333333
# Predicted congestion for segment 773 = 0.651111111111
# Predicted congestion for segment 774 = 0.759259259259
# Predicted congestion for segment 775 = 0.77264957265
# Predicted congestion for segment 776 = 0.749523809524
# Predicted congestion for segment 777 = 0.825396825397
# Predicted congestion for segment 778 = 0.761111111111
# Predicted congestion for segment 779 = 0.625287356322
# Predicted congestion for segment 780 = 0.676041666667
# Predicted congestion for segment 781 = 0.773895582329
# Predicted congestion for segment 782 = 0.698484848485
# Predicted congestion for segment 783 = 0.9304
# Predicted congestion for segment 784 = 0.808333333333
# Predicted congestion for segment 785 = 0.777419354839
# Predicted congestion for segment 786 = 0.832134292566
# Predicted congestion for segment 787 = 0.759047619048
# Predicted congestion for segment 788 = 0.625641025641
# Predicted congestion for segment 789 = 0.642857142857
# Predicted congestion for segment 790 = 0.730833333333
# Predicted congestion for segment 791 = 0.599099099099
# Predicted congestion for segment 792 = 0.7
# Predicted congestion for segment 793 = 0.591666666667
# Predicted congestion for segment 795 = 0.716666666667
# Predicted congestion for segment 798 = 0.90462962963
# Predicted congestion for segment 799 = 0.951904761905
# Predicted congestion for segment 800 = 0.935185185185
# Predicted congestion for segment 801 = 0.784848484848
# Predicted congestion for segment 802 = 0.76875
# Predicted congestion for segment 803 = 0.807344632768
# Predicted congestion for segment 804 = 0.738164251208
# Predicted congestion for segment 805 = 0.877506775068
# Predicted congestion for segment 806 = 0.794133333333
# Predicted congestion for segment 809 = 0.945045045045
# Predicted congestion for segment 810 = 0.993650793651
# Predicted congestion for segment 811 = 1.07063492063
# Predicted congestion for segment 812 = 0.871604938272
# Predicted congestion for segment 813 = 0.738988095238
# Predicted congestion for segment 814 = 0.770114942529
# Predicted congestion for segment 815 = 0.783333333333
# Predicted congestion for segment 816 = 1.05
# Predicted congestion for segment 817 = 0.771428571429
# Predicted congestion for segment 824 = 0.749612403101
# Predicted congestion for segment 825 = 0.766666666667
# Predicted congestion for segment 826 = 0.810648148148
# Predicted congestion for segment 827 = 0.933103448276
# Predicted congestion for segment 853 = 0.871428571429
# Predicted congestion for segment 854 = 0.689379084967
# Predicted congestion for segment 859 = 0.846509009009
# Predicted congestion for segment 860 = 0.522885572139
# Predicted congestion for segment 861 = 0.595801847187
# Predicted congestion for segment 866 = 0.766666666667
# Predicted congestion for segment 867 = 0.561904761905
# Predicted congestion for segment 871 = 0.59696969697
# Predicted congestion for segment 872 = 0.535384615385
# Predicted congestion for segment 873 = 0.675675675676
# Predicted congestion for segment 874 = 0.633333333333
# Predicted congestion for segment 875 = 0.706666666667
# Predicted congestion for segment 878 = 0.575897435897
# Predicted congestion for segment 879 = 0.557142857143
# Predicted congestion for segment 880 = 0.661666666667
# Predicted congestion for segment 881 = 0.754411764706
# Predicted congestion for segment 882 = 0.64407530454
# Predicted congestion for segment 883 = 0.646234446627
# Predicted congestion for segment 886 = 0.919190140845
# Predicted congestion for segment 887 = 1.66654846336
# Predicted congestion for segment 888 = 1.61677753141
# Predicted congestion for segment 893 = 1.13333333333
# Predicted congestion for segment 894 = 1.53705642816
# Predicted congestion for segment 898 = 0.86962962963
# Predicted congestion for segment 899 = 0.716888888889
# Predicted congestion for segment 900 = 0.705263157895
# Predicted congestion for segment 903 = 0.833333333333
# Predicted congestion for segment 904 = 0.802564102564
# Predicted congestion for segment 907 = 0.6421875
# Predicted congestion for segment 912 = 0.729914529915
# Predicted congestion for segment 913 = 0.838596491228
# Predicted congestion for segment 914 = 0.655367231638
# Predicted congestion for segment 917 = 0.734722222222
# Predicted congestion for segment 918 = 0.828985507246
# Predicted congestion for segment 921 = 0.65811965812
# Predicted congestion for segment 926 = 0.904609929078
# Predicted congestion for segment 927 = 0.811666666667
# Predicted congestion for segment 928 = 0.6
# Predicted congestion for segment 929 = 0.638333333333
# Predicted congestion for segment 930 = 0.620091324201
# Predicted congestion for segment 933 = 0.791666666667
# Predicted congestion for segment 934 = 0.763768115942
# Predicted congestion for segment 935 = 0.595061728395
# Predicted congestion for segment 936 = 0.633333333333
# Predicted congestion for segment 937 = 0.658333333333
# Predicted congestion for segment 938 = 0.735714285714
# Predicted congestion for segment 939 = 0.611403508772
# Predicted congestion for segment 940 = 0.642424242424
# Predicted congestion for segment 941 = 0.810144927536
# Predicted congestion for segment 942 = 0.664035087719
# Predicted congestion for segment 943 = 0.762962962963
# Predicted congestion for segment 944 = 0.820833333333
# Predicted congestion for segment 945 = 0.849657534247
# Predicted congestion for segment 946 = 0.961875
# Predicted congestion for segment 949 = 0.733333333333
# Predicted congestion for segment 950 = 1.06666666667
# Predicted congestion for segment 954 = 0.738095238095
# Predicted congestion for segment 955 = 0.597222222222
# Predicted congestion for segment 962 = 0.542857142857
# Predicted congestion for segment 966 = 0.790885416667
# Predicted congestion for segment 967 = 0.932222222222
# Predicted congestion for segment 968 = 1.00884353741
# Predicted congestion for segment 969 = 0.832183908046
# Predicted congestion for segment 970 = 0.784615384615
# Predicted congestion for segment 971 = 0.63731884058
# Predicted congestion for segment 972 = 0.8
# Predicted congestion for segment 974 = 0.799019607843
# Predicted congestion for segment 975 = 0.86380952381
# Predicted congestion for segment 976 = 1.02444444444
# Predicted congestion for segment 977 = 0.797916666667
# Predicted congestion for segment 978 = 0.68303030303
# Predicted congestion for segment 979 = 0.676811594203
# Predicted congestion for segment 980 = 0.886274509804
# Predicted congestion for segment 1001 = 0.731481481481
# Predicted congestion for segment 1003 = 0.776388888889
# Predicted congestion for segment 1018 = 0.848148148148
# Predicted congestion for segment 1024 = 0.752380952381
# Predicted congestion for segment 1025 = 0.85
# Predicted congestion for segment 1026 = 0.516260162602
# Predicted congestion for segment 1027 = 0.824117647059
# Predicted congestion for segment 1028 = 0.542424242424
# Predicted congestion for segment 1029 = 0.632738095238
# Predicted congestion for segment 1033 = 0.664187327824
# Predicted congestion for segment 1034 = 0.689489489489
# Predicted congestion for segment 1035 = 0.511635220126
# Predicted congestion for segment 1036 = 0.633545647558
# Predicted congestion for segment 1037 = 0.772029442692
# Predicted congestion for segment 1038 = 0.61746031746
# Predicted congestion for segment 1049 = 0.826984126984
# Predicted congestion for segment 1051 = 0.8
# Predicted congestion for segment 1052 = 0.6
# Predicted congestion for segment 1053 = 0.718087855297
# Predicted congestion for segment 1054 = 0.675925925926
# Predicted congestion for segment 1057 = 0.689826839827
# Predicted congestion for segment 1058 = 0.746923783287
# Predicted congestion for segment 1059 = 0.673333333333
# Predicted congestion for segment 1060 = 0.766666666667
# Predicted congestion for segment 1061 = 0.7
# Predicted congestion for segment 1062 = 0.688888888889
# Predicted congestion for segment 1063 = 0.7
# Predicted congestion for segment 1101 = 0.696666666667
# Predicted congestion for segment 1105 = 0.862269503546
# Predicted congestion for segment 1125 = 0.922222222222
# Predicted congestion for segment 1126 = 0.783333333333
# Predicted congestion for segment 1127 = 0.895588235294
# Predicted congestion for segment 1132 = 0.913333333333
# Predicted congestion for segment 1133 = 0.929032258065
# Predicted congestion for segment 1134 = 0.782010582011
# Predicted congestion for segment 1178 = 0.587195121951
# Predicted congestion for segment 1181 = 0.76
# Predicted congestion for segment 1182 = 0.730555555556
# Predicted congestion for segment 1183 = 0.674914089347
# Predicted congestion for segment 1184 = 0.803174603175
# Predicted congestion for segment 1185 = 0.763003663004
# Predicted congestion for segment 1186 = 0.783333333333
# Predicted congestion for segment 1187 = 0.702898550725
# Predicted congestion for segment 1188 = 0.611904761905
# Predicted congestion for segment 1189 = 0.668046928916
# Predicted congestion for segment 1192 = 0.662841530055
# Predicted congestion for segment 1193 = 0.753736654804
# Predicted congestion for segment 1201 = 0.785897435897
# Predicted congestion for segment 1202 = 0.833333333333
# Predicted congestion for segment 1203 = 0.628947368421
# Predicted congestion for segment 1204 = 0.701075268817
# Predicted congestion for segment 1205 = 0.762765957447
# Predicted congestion for segment 1206 = 0.712179487179
# Predicted congestion for segment 1207 = 0.684482758621
# Predicted congestion for segment 1208 = 0.763387978142
# Predicted congestion for segment 1209 = 0.747712418301
# Predicted congestion for segment 1210 = 0.782730923695
# Predicted congestion for segment 1211 = 0.893798449612
# Predicted congestion for segment 1212 = 0.779583333333
# Predicted congestion for segment 1213 = 0.800952380952
# Predicted congestion for segment 1214 = 0.746031746032
# Predicted congestion for segment 1215 = 0.632173913043
# Predicted congestion for segment 1216 = 0.62962962963
# Predicted congestion for segment 1217 = 0.89
# Predicted congestion for segment 1218 = 0.627672955975
# Predicted congestion for segment 1219 = 0.502298850575
# Predicted congestion for segment 1220 = 0.615350877193
# Predicted congestion for segment 1221 = 0.665476190476
# Predicted congestion for segment 1222 = 0.592248062016
# Predicted congestion for segment 1223 = 0.784102564103
# Predicted congestion for segment 1224 = 0.853623188406
# Predicted congestion for segment 1225 = 0.651851851852
# Predicted congestion for segment 1226 = 0.744444444444
# Predicted congestion for segment 1227 = 0.665860215054
# Predicted congestion for segment 1228 = 0.751587301587
# Predicted congestion for segment 1229 = 0.811111111111
# Predicted congestion for segment 1230 = 0.641798941799
# Predicted congestion for segment 1231 = 0.681818181818
# Predicted congestion for segment 1237 = 0.841935483871
# Predicted congestion for segment 1238 = 0.703244837758
# Predicted congestion for segment 1239 = 0.707745098039
# Predicted congestion for segment 1240 = 0.743835616438
# Predicted congestion for segment 1241 = 0.85641025641
# Predicted congestion for segment 1242 = 0.711904761905
# Predicted congestion for segment 1243 = 0.791722595078
# Predicted congestion for segment 1244 = 0.794117647059
# Predicted congestion for segment 1245 = 0.770588235294
# Predicted congestion for segment 1246 = 0.802402402402
# Predicted congestion for segment 1247 = 0.902564102564
# Predicted congestion for segment 1248 = 0.874257425743
# Predicted congestion for segment 1249 = 0.835460992908
# Predicted congestion for segment 1250 = 0.861971830986
# Predicted congestion for segment 1251 = 0.671361502347
# Predicted congestion for segment 1252 = 0.731355932203
# Predicted congestion for segment 1253 = 0.863364779874
# Predicted congestion for segment 1254 = 0.632666666667
# Predicted congestion for segment 1255 = 0.65
# Predicted congestion for segment 1256 = 0.656888888889
# Predicted congestion for segment 1257 = 0.431818181818
# Predicted congestion for segment 1258 = 0.634591194969
# Predicted congestion for segment 1259 = 0.598449612403
# Predicted congestion for segment 1260 = 0.824444444444
# Predicted congestion for segment 1261 = 0.396794871795
# Predicted congestion for segment 1262 = 0.714379084967
# Predicted congestion for segment 1263 = 0.576595744681
# Predicted congestion for segment 1264 = 0.655782312925
# Predicted congestion for segment 1265 = 0.718055555556
# Predicted congestion for segment 1266 = 0.579420289855
# Predicted congestion for segment 1269 = 0.550628019324
# Predicted congestion for segment 1270 = 0.638095238095
# Predicted congestion for segment 1271 = 0.728571428571
# Predicted congestion for segment 1272 = 0.67
# Predicted congestion for segment 1273 = 0.7
# Predicted congestion for segment 1274 = 0.750326797386
# Predicted congestion for segment 1276 = 0.882469135802
# Predicted congestion for segment 1277 = 0.910526315789
# Predicted congestion for segment 1288 = 0.710416666667
# Predicted congestion for segment 1289 = 0.640303030303
# Predicted congestion for segment 1290 = 0.72904040404
# Predicted congestion for segment 1291 = 0.772727272727
# Predicted congestion for segment 1292 = 0.67012195122
# Predicted congestion for segment 1293 = 0.649777777778
# Predicted congestion for segment 1294 = 0.492432432432
# Predicted congestion for segment 1295 = 0.689215686275
# Predicted congestion for segment 1296 = 0.552820512821
# Predicted congestion for segment 1297 = 0.674193548387
# Predicted congestion for segment 1298 = 0.53
# Predicted congestion for segment 1299 = 0.611111111111
# Predicted congestion for segment 1300 = 0.642723004695
# Predicted congestion for segment 1301 = 0.579166666667
# Predicted congestion for segment 1304 = 0.70406504065
# Predicted congestion for segment 1305 = 0.674385964912
# Predicted congestion for segment 1306 = 0.765079365079
# Predicted congestion for segment 1307 = 0.678717948718
# Predicted congestion for segment 1308 = 0.733862433862
# Predicted congestion for segment 1309 = 0.719277108434

# %% [markdown]
# ### <a name="viz"></a> 7. Predicted Traffic Congestion Visualization

# %% [markdown]
# While we can see the congestion values for each of the road segments above, traffic congestion on roads is much better understood when visualized on a map. This is exactly what we will do next. But since the road segment geometries were not part of our data features, we need to obtain them from COS. For this, we can once again use a SQL query to get the geometries for road segments in Chicago, which is where our road segments were from.

# %%
sql = """
SELECT SegmentID, ST_Y(ST_StartPoint(Segment)) as start_lat,
                  ST_X(ST_StartPoint(Segment)) as start_lon,
                  ST_Y(ST_EndPoint(Segment)) as end_lat, 
                  ST_X(ST_EndPoint(Segment)) as end_lon FROM cos://us-east/mytestbucket123/segment_locations.parquet STORED AS PARQUET
                    WHERE ST_Contains(ST_WKTToSQL('POLYGON((-87.66182361726857 42.013649516597454,-87.78404651765919 42.00956804496257,-87.78541980867482 41.90335786993515,-87.71126209383107 41.74268615114427,-87.61513172273732 41.71296382783499,-87.54784046297169 41.746784702779486,-87.61650501375294 41.86246067685847,-87.66182361726857 42.013649516597454))'), Segment) INTO {}
""".format(targeturl)

# %%
segment_locations = sqlClient.run_sql(sql)
if isinstance(segment_locations, str):
    print(segment_locations)

# %% [markdown]
# 'segment_locations' contains the road segment identifiers as well as the corresponding line segment geometries for those road segments. We also have the per road segment congestion predictions in the 'predicted' dictionary that we obtained in the last step. We will use these road segment geometries and predictions to visualize the results.
#
# For each major road segment in downtown chicago, **a traffic congestion value of or greater than 1.5 is denoted by a red color line segment**, a **traffic congestion value between 1.0 and 1.5 is denoted by an orange color line segment** and **a traffic congestion value of or less than 1.0 is denoted by a green color line segment**.

# %%
m = folium.Map([41.867169, -87.678114], zoom_start=11)
for index, row in segment_locations.iterrows():
    locations = [[row['start_lat'], row['start_lon']], [row['end_lat'], row['end_lon']]]
    if row['SegmentID'] in predicted:
        val = row['SegmentID']
        congestion = predicted[val]
        color = 'green'
        if congestion > 1.0 and congestion < 1.5:
            color = 'orange'
        elif congestion >= 1.5:
            color = 'red'
        folium.PolyLine(locations,weight=5,color=color).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
